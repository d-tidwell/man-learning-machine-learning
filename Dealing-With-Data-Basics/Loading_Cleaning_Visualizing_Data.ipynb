# %% [markdown]
# <a href="https://colab.research.google.com/github/chefdarek/DS-Unit-1-Sprint-1-Dealing-With-Data/blob/master/LS_DS_111_A_First_Look_at_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#gets datasets native to seaborn
sns.get_dataset_names()
#rename dataframe to df to shorten for conv.
df = sns.load_dataset("tips")

# %%
#seaborn.load_dataset
# seaborn.load_dataset(name, cache=True, data_home=None, **kws)¶
# Load a dataset from the online repository (requires internet).

# Parameters:	
# name : str

# Name of the dataset (name.csv on https://github.com/mwaskom/seaborn-data). You can obtain list of available 
# datasets using get_dataset_names()

# cache : boolean, optional

# If True, then cache data locally and use the cache on subsequent calls

# data_home : string, optional

# The directory in which to cache data. By default, uses ~/seaborn-data/

# kws : dict, optional

# Passed to pandas.read_csv
sns.get_dataset_names()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/utils.py:376: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 376 of the file /usr/local/lib/python3.6/dist-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset("tips")

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", data=df);

# %%
sns.pairplot(df, hue='smoker', palette= 'OrRd',height=2.5);

# %%
df['tip_pct'] = 100 * df['tip'] / df['total_bill']

g = sns.FacetGrid(df, col="sex", hue="time")
g.map(plt.scatter, "total_bill", "tip_pct", cmap = 'plasma', alpha=.7)
g.add_legend();

# %%
sns.relplot(x="total_bill", y="tip_pct", color = "green", data=df);

# %%
with sns.axes_style('white'):
    sns.jointplot("tip_pct", "total_bill", data=df, cmap= "Spectral_r", kind='hex')

# %%
sns.violinplot("sex", "tip_pct", data=df,
               palette=["lightblue", "pink"]);

# %%
sns.catplot(x="day", y="total_bill", hue="time", kind="point", data=df);

# %% [markdown]
# ### Assignment questions
#
#
#
# *In the above visualizations, I took the dataset "Tips" from the seaborn built in library and evaluated how in the restaurant industry one might gauge the variety of potential variables that could impact tip percentages. Staff retention is invaluable in todays industry as the demand for quality staff far exceeds supply. The hospitality industry employs over one third of the American workforce. Evaulations such as these may prove useful to owners and stakeholders within the operation such that they are able to augment their service tactics and overall business strategy to more effectively identify guests service satisfaction while increasing the mean wage of their workforce without reaching into the businesses thin margins of profit.*
# *italicized text*
#
#
# *The most challenging portion was picking appropriate styles of graphs from the seemingly endless ocean of potential manners available in which to represent it.  A close second, most challenging piece would be the retention of various variable parameters one must or is able to envoke in order to have an effect color, size, maker, etc etc etc.*
# *italicized text*
#
#
# *What struck me the most while doing this excersise was the vastness of ways in which data can be compared and contrasted in such a visual way with quantifiable data.  In a past life I used visuals for a myriad of abstract represntational information wether it be on the plate or through a projector at a music festival, but to combine the notion of color and shape to concrete points of date is a powerful tool with an explicit obvious and hopefully direct impact. *
#
#
#
# *As I go forward in the data science journey, I hope to be able with more time to really understand the fundementals of all of the various visual representations on a deeper level to be able to effectively enhance and tell real stories with each piece.*
# *italicized text*

# %% [markdown]
# Grow Mart, Plant Depot, and Trees’R’Us are gardening stores in a city. Grow Mart and Plant Depot were both founded in 1973, and Trees’R’Us was founded in 1985. Grow Mart has annual revenue of $265k and expenses of $183k, Plant Depot has $302k revenue and $240k expenses, and Trees’R’Us has $123k revenue and $130k expenses.

# %%
grow_mart = {"fnd": 1973, "an_rev":265000, "an_exp":183000, "is_profitable": True}
plant_depot = {"fnd": 1973, "an_rev":302000, "an_exp":240000, "is_profitable": True}
trees_r_us = {"fnd": 1985, "an_rev":132000, "an_exp":183000, "is_profitable": False}
stores = [grow_mart, plant_depot, trees_r_us]

# %%
import pandas as pd
import matplotlib.pyplot as pl

# %%
# #this method the index is now only a set of numbers 
# pd.DataFrame([grow_mart, plant_depot, trees_r_us])

# %%
# #this method now the index are named, however it is manual entry
# pd.DataFrame([grow_mart, plant_depot, trees_r_us], index = ["Grow_Mart","Plant_Depot","Trees_R_Us"])

# %%
df = {'Stores': ['Grow_Mart', 'Plant_Depot', 'Trees_r_Us'],'fnd': [1973, 1973, 1985], 'annual_rev': [265000, 302000,132000], 'an_exp':[183000,240000,183000],
     'is_profitable':[True,True,False]}

pd.DataFrame(df).set_index('Stores')
# Out:
#               fnd  annual_rev  an_exp  is_profitable
# Stores
# Grow_Mart    1973      265000  183000           True
# Plant_Depot  1973      302000  240000           True
# Trees_r_Us   1985      132000  183000          False

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as pl

# %%
# colors = ["windows blue", "amber", "greyish", "black", "gold"]
# sns.palplot(sns.xkcd_palette(colors))

sns.set()
 
# Load the brain networks example dataset
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)
 
# Select a subset of the networks
used_networks = [1, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]
 
# Create a custom palette to identify the networks
network_pal = sns.color_palette("YlOrRd")#(len(used_networks),
#                                     light=.9, dark=.1, reverse=True,
#                                     start=1, rot=-2
network_lut = dict(zip(map(str, used_networks), network_pal))
 
# Convert the palette to vectors that will be drawn on the side of the matrix
networks = df.columns.get_level_values("network")
network_colors = pd.Series(networks, index=df.columns).map(network_lut)
 
# Create a custom colormap for the heatmap values
#cmap = YlOrRd
#cmap = sns.palplot(sns.diverging_palette(10, 220, sep=80, n=7)
colormap = sns.diverging_palette(h_neg=300, h_pos=100, s=90, l=30, as_cmap=True)
 
# Draw the full plot
sns.clustermap(df.corr(), row_colors=network_colors, linewidths=.5,
               col_colors=network_colors, figsize=(9, 9), cmap=colormap)

# %%
df.describe()
# Out:
# network           1                       5                       6  \
# node              1                       1                       1
# hemi             lh          rh          lh          rh          lh
# count    920.000000  920.000000  920.000000  920.000000  920.000000
# mean      -0.014230   -0.024642   -0.002234   -0.013988   -0.005341
# std       48.906340   53.389574   34.728464   38.946151   40.766629
# min     -228.101303 -203.172806 -104.299438 -104.826241 -103.748665
# 25%      -28.645570  -33.573225  -24.474397  -25.207906  -24.994578
# 50%        0.795935    0.167886   -0.444854   -1.368788   -2.186019
# 75%       29.269680   34.075309   23.062621   24.235983   22.208238
# max      163.615540  180.641937  117.555420  125.433167  243.687378
#
# network                                               7              \
# node                          2                       1
# hemi             rh          lh          rh          lh          rh
# ...

# %%
df.head()
# Out:
# network          1                     5                     6             \
# node             1                     1                     1
# hemi            lh         rh         lh         rh         lh         rh
# 0        56.055744  92.031036 -35.898861  -1.889181   5.898688 -43.692322
# 1        55.547253  43.690075  19.568010  15.902983 -23.231823 -10.745867
# 2        60.997768  63.438793  19.247454  37.209419   2.392153  16.509109
# 3        18.514868  12.657158  32.896915  11.199619 -14.665752   2.073715
# 4        -2.527392 -63.104668  18.396759   3.219077 -41.856911 -24.690414
#
# network                                7               ...             16  \
# node             2                     1               ...              3
# hemi            lh         rh         lh         rh    ...             rh
# 0       -47.664265  12.284122   1.566538 -13.042585    ...       0.607904
# 1        10.269546  31.275831 -26.309488 -18.077026    ...      57.495071
# ...
